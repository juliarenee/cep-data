# %% [markdown]
# # Two federal programs at odds
# ## School lunch debt in Durham Public Schools and competition between CEP and Title I

# %%
# Load packages
require(ggplot2)
require(dplyr)
require(tidyr)
require(knitr)
require(stringr)

# Don't load strings as factors
options('stringsAsFactors'=FALSE)

# Load lunch debt and 2018-19 banding data
debt = read.csv('./data/meal_debt.csv')
bands = read.csv('./data/banding_1718.csv')

# Load CEP eligibility data
# File names as list
cep.list = list.files('./data') %>%
    grep('cep', ., value=TRUE) %>%
    paste('./data/', ., sep='')

# Read files
cep.dat = lapply(cep.list, function(x) read.csv(x))

# Add year
year = c('2014-15', '2015-16', '2016-17', '2017-18', '2018-19')
for(i in 1:length(cep.dat)) {
  cep.dat[[i]]$year = year[i]
}
                 
# Merge to one dataset
cep = do.call(plyr::rbind.fill, cep.dat)
                 
# Add missing school numbers for 2014-15 CEP eligibility data
school_no_key = cep %>%
  filter(!is.na(school_no)) %>%
  select(school_name, school_no) %>%
  unique()
cep$school_no[cep$year=="2014-15"] = school_no_key$school_no[school_no_key$school_name %in% cep$school_name[cep$year=='2014-15']]

                 
# Filter to Durham
cep = cep %>%
    filter(lea_no == 320)
                 
# Control for data types
                 
# Merge lunch debt and CEP data
df = left_join(cep, debt, by = c('school_name', 'school_no', 'year'))
# Out:
# Error: Can't join on 'school_no' x 'school_no' because of incompatible types (integer / character)
# Traceback:
#
# 1. left_join(cep, debt, by = c("school_name", "school_no", "year"))
# 2. left_join.data.frame(cep, debt, by = c("school_name", "school_no",
#  .     "year"))
# 3. as.data.frame(left_join(tbl_df(x), y, by = by, copy = copy, ...))
# 4. left_join(tbl_df(x), y, by = by, copy = copy, ...)
# 5. left_join.tbl_df(tbl_df(x), y, by = by, copy = copy, ...)
# 6. left_join_impl(x, y, by_x, by_y, aux_x, aux_y, na_matches, environment())

# %%
df
# Out:
#     school_name                    lea_name              lea_no isp   eligible
# 1   Bethesda Elementary            Durham Public Schools 320    0.519 X
# 2   Brogden Middle                 Durham Public Schools 320    0.449 X
# 3   Burton Elementary              Durham Public Schools 320    0.628 X
# 4   C C Spaulding Elementary       Durham Public Schools 320    0.750 X
# 5   Club Boulevard Elementary      Durham Public Schools 320    0.313
# 6   E K Powe Elementary            Durham Public Schools 320    0.425 X
# 7   Eastway Elementary             Durham Public Schools 320    0.715 X
# 8   Eno Valley Elementary          Durham Public Schools 320    0.546 X
# 9   Fayetteville Street Elementary Durham Public Schools 320    0.674 X
# 10  Forest View Elementary         Durham Public Schools 320    0.353
# 11  George L Carrington Middle     Durham Public Schools 320    0.392
# 12  Glenn Elementary               Durham Public Schools 320    0.565 X
# 13  Hillandale Elementary          Durham Public Schools 320    0.400 X
# 14  Hillside High                  Durham Public Schools 320    0.408 X
# 15  Holt Elementary                Durham Public Schools 320    0.487 X
# 16  Hope Valley Elementary         Durham Public Schools 320    0.384
# 17  James E Shepard Middle         Durham Public Schools 320    0.412 X
# 18  Lakeview School                Durham Public Schools 320    0.700 X
# 19  Lakewood Elementary            Durham Public Schools 320    0.640 X
# 20  Little River Elementary        Durham Public Schools 320    0.308
# 21  Lowe's Grove Middle            Durham Public Schools 320    0.500 X
# 22  Lucas Middle School            Durham Public Schools 320    0.336
# 23  Merrick-Moore Elementary       Durham Public Schools 320    0.579 X
# 24  Neal Middle                    Durham Public Schools 320    0.513 X
# 25  Northern High                  Durham Public Schools 320    0.358
# 26  Oak Grove Elementary           Durham Public Schools 320    0.460 X
# 27  Parkwood Elementary            Durham Public Schools 320    0.431 X
# 28  Performance Learning Center    Durham Public Schools 320    0.360
# 29  R N Harris Elementary          Durham Public Schools 320    0.568 X
# 30  Sandy Ridge Elementary         Durham Public Schools 320    0.359
# ⋮   ⋮                              ⋮                     ⋮      ⋮     ⋮
# 216 Lakewood Elementary            Durham Public Schools 320    0.56  NA
# 217 Little River                   Durham Public Schools 320    0.25  NA
# 218 Lakeview                       Durham Public Schools 320    0.83  NA
# 219 Lakewood Middle                Durham Public Schools 320    0.25  NA
# 220 Lucas                          Durham Public Schools 320    0.48  NA
# 221 Fayetteville Street            Durham Public Schools 320    0.63  NA
# 222 Lowe's Grove                   Durham Public Schools 320    0.57  NA
# 223 George Watts                   Durham Public Schools 320    0.19  NA
# 224 Mangum                         Durham Public Schools 320    0.16  NA
# 225 Merrick Moore                  Durham Public Schools 320    0.60  NA
# 226 Middle College                 Durham Public Schools 320    0.17  NA
# 227 Morehead                       Durham Public Schools 320    0.22  NA
# 228 Neal                           Durham Public Schools 320    0.52  NA
# 229 Northern                       Durham Public Schools 320    0.42  NA
# 230 Oak Grove                      Durham Public Schools 320    0.49  NA
# 231 Parkwood                       Durham Public Schools 320    0.53  NA
# 232 E K Powe                       Durham Public Schools 320    0.36  NA
# 233 Pearsontown                    Durham Public Schools 320    0.21  NA
# 234 Riverside                      Durham Public Schools 320    0.35  NA
# 235 Githens                        Durham Public Schools 320    0.39  NA
# 236 R N Harris                     Durham Public Schools 320    0.49  NA
# 237 Southern                       Durham Public Schools 320    0.46  NA
# 238 Sandy Ridge                    Durham Public Schools 320    0.49  NA
# 239 Rogers Herr                    Durham Public Schools 320    0.28  NA
# 240 Southwest                      Durham Public Schools 320    0.43  NA
# 241 C C Spaulding                  Durham Public Schools 320    0.69  NA
# 242 Spring Valley                  Durham Public Schools 320    0.38  NA
# 243 W G Pearson                    Durham Public Schools 320    0.58  NA
# 244 Y E Smith                      Durham Public Schools 320    0.69  NA
# 245 Hillside New Tech              Durham Public Schools 320    0.37  NA
#     year    school_no.x participating enrollment grade_level school_no.y unpaid
# 1   2014-15 360         NA            NA         NA           NA             NA
# 2   2014-15 364         NA            NA         NA           NA             NA
# 3   2014-15 384         NA            NA         NA           NA             NA
# 4   2014-15 388         NA            NA         NA           NA             NA
# 5   2014-15 392         NA            NA         NA           NA             NA
# 6   2014-15 396         NA            NA         NA           NA             NA
